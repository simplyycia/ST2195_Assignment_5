# %%
def is_divisible_by_k(x, k):
  '''
  Checks whether x is divisible by k.
  '''
  assert x%k == 0
'''
Store all the integers that are multiples of 2 or 5 or 7 that are lower or equal to 1000 (excluding
doubles)
'''
x = ()
for i in range(1000):
  if (is_divisible_by_k(x, 2) & is_divisible_by_k(x, 3)) | is_divisible_by_k(x, 7):
   x.append(i)
  
'''
Sum all the integers that are multiples of 2 or 5 or 7 that are lower or equal to 1000 (excluding
doubles)
'''
sum(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 12
#      10 x = ()
#      11 for i in range(1000):
# ---> 12   if (is_divisible_by_k(x, 2) & is_divisible_by_k(x, 3)) | is_divisible_by_k(x, 7):
#      13    x.append(i)
#      15 '''
#      16 Sum all the integers that are multiples of 2 or 5 or 7 that are lower or equal to 1000 (excluding
#      17 doubles)
#      18 '''
#
# Cell In[4], line 5, in is_divisible_by_k(x, k)
#       1 def is_divisible_by_k(x, k):
#       2   '''
#       3   Checks whether x is divisible by k.
#       4   '''
# ----> 5   assert x%k == 0
#
# TypeError: unsupported operand type(s) for %: 'tuple' and 'int'
